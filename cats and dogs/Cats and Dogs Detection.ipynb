# %% [markdown]
# # **import** **libraries**

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# # **MOUNT DATA FROM DRIVE**

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **DATA PREPROCESING**

# %% [markdown]
# **TRAINNING DATA PROCESSIONG**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range= 0.2,
                                   zoom_range= 0.2,
                                   horizontal_flip= True)
training_set = train_datagen.flow_from_directory('training_set',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.

# %% [markdown]
# **TESTING DATA PROCESSING**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('test_set',
                                                 target_size=(64, 64),
                                                 batch_size=32,
                                                 class_mode='binary')
# Out:
# Found 2023 images belonging to 2 classes.

# %% [markdown]
# # **BUILDING THE CNN**

# %% [markdown]
# **INITIALISOMG** **CNN**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# **step-1: Convolution**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64,64,3]))

# %% [markdown]
# **step-2: Pooling**

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Adding a secong convolutional layer**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64,64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **step-3: Flatening**

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# **Step-4: Full Connection**

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# **Step-5: Output Layer**

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # **Training the CNN**

# %% [markdown]
# **Compiling the CNN**

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Training the CNN on training set and evaluating it on testig set**

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs= 2)
# Out:
# Epoch 1/2
# 251/251 [==============================] - 4051s 16s/step - loss: 0.6680 - accuracy: 0.5839 - val_loss: 0.6194 - val_accuracy: 0.6550
# Epoch 2/2
# 251/251 [==============================] - 105s 420ms/step - loss: 0.6084 - accuracy: 0.6697 - val_loss: 0.5968 - val_accuracy: 0.6802

# %% [markdown]
# # **Prediction**

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('images/Cats_Test0.png', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = "dog"
else:
  prediction = "cat"

# %%
import os
images = os.listdir('images')

for image in images:
  test_image = image.load_img('image', target_size=(64,64))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  result = cnn.predict(test_image)
  training_set.class_indices
  if result[0][0] == 1:
    prediction = "dog"
  else:
    prediction = "cat"

# %%
print(prediction)
